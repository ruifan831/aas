# %%
from model import Backbone,RegionProposalNetwork,GeneralizedRCNN
from data.dataset import VOCDataset,Transform
from torch.utils.data import DataLoader
from model.utils.anchor import AnchorGenerator
from model.utils.creator_tool import ProposalTargetCreator
from torchvision import transforms
import matplotlib
import torch

root="../VOCdevkit/VOC2007/"
# root = "/home/ruifanxu/Desktop/ComputerVision/Faster_RCNN/VOCdevkit/VOC2007/"
trainData = VOCDataset(root,transform = Transform())
loader = DataLoader(trainData,batch_size = 1)

# %%
model,classifier = Backbone.vggbackbone(True)
rpnhead= RegionProposalNetwork.RPNHead(512,9)
anGen = AnchorGenerator()
proposalTarget = ProposalTargetCreator()
rpn = RegionProposalNetwork.RegionProposalNetwork(anGen,rpnhead,0.5,0.5,1,0.5,1000,1000,0.7)

# %%
for i,(img,target) in enumerate(loader):
    print(img.shape)
    print(target)
    temp = model(img)
    rpn_offset, rpn_score, rois,roi_indices,anchors=rpn(temp,img,1)
    result =proposalTarget(rois,target["boxes"][0],target["labels"])
    break
# Out:
# 5
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[336.0000, 419.2000, 540.8000, 516.8000],
#          [420.8000, 262.4000, 593.6000, 403.2000],
#          [388.8000,   6.4000, 596.8000, 105.6000],
#          [308.8000, 384.0000, 476.8000, 470.4000],
#          [296.0000, 441.6000, 350.4000, 497.6000]]]), 'labels': tensor([[9, 9, 9, 9, 9]]), 'image_id': ['000005']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 88.2883, 252.2800, 592.7928, 899.1980]]]), 'labels': tensor([[7]]), 'image_id': ['000007']}
# 4
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[273.6000, 108.8000, 526.4000, 430.4000],
#          [224.0000, 238.4000, 452.8000, 364.8000],
#          [320.0000, 454.4000, 528.0000, 521.6000],
#          [315.2000, 411.2000, 524.8000, 473.6000]]]), 'labels': tensor([[13, 15, 15, 15]]), 'image_id': ['000009']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[172.9730, 279.3100, 484.6847, 630.7000]]]), 'labels': tensor([[7]]), 'image_id': ['000012']}
# 1
# torch.Size([1, 3, 898, 600])
# {'boxes': tensor([[[127.5160, 163.4731, 847.7120, 546.1078]]]), 'labels': tensor([[2]]), 'image_id': ['000016']}
# 2
# torch.Size([1, 3, 600, 791])
# {'boxes': tensor([[[100.5495, 303.2167, 326.3736, 458.1208],
#          [126.9231, 146.6646, 552.1978, 662.4625]]]), 'labels': tensor([[15, 13]]), 'image_id': ['000017']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[139.2000, 368.0000, 408.0000, 771.2000],
#          [179.2000,  16.0000, 412.8000, 424.0000]]]), 'labels': tensor([[8, 8]]), 'image_id': ['000019']}
# 1
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[235.2000,  51.2000, 664.0000, 592.0000]]]), 'labels': tensor([[7]]), 'image_id': ['000020']}
# 4
# torch.Size([1, 3, 893, 600])
# {'boxes': tensor([[[417.9240,   0.0000, 691.1820, 323.2143],
#          [ 62.5100, 373.2143, 859.0660, 598.2143],
#          [144.6660,  80.3571, 650.1040, 301.7857],
#          [321.4800,  17.8571, 746.5480, 251.7857]]]), 'labels': tensor([[12, 15, 15, 15]]), 'image_id': ['000021']}
# 6
# torch.Size([1, 3, 898, 600])
# {'boxes': tensor([[[411.2840,  14.3713, 896.2040, 438.3234],
#          [393.3240, 411.3773, 896.2040, 598.2036],
#          [317.8920,   1.7964, 896.2040, 159.8802],
#          [  0.0000,   1.7964, 660.9280, 208.3832],
#          [  1.7960,   3.5928, 827.9560, 434.7306],
#          [  0.0000, 402.3952, 871.0600, 598.2036]]]), 'labels': tensor([[ 2,  2,  2, 15, 15, 15]]), 'image_id': ['000023']}
# 1
# torch.Size([1, 3, 600, 896])
# {'boxes': tensor([[[293.7314, 349.4400, 440.5970, 874.4960]]]), 'labels': tensor([[19]]), 'image_id': ['000024']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[223.4234, 160.3780, 380.1802, 605.4720]]]), 'labels': tensor([[7]]), 'image_id': ['000026']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[326.4000,  56.0000, 460.8000, 286.4000],
#          [254.4000,  80.0000, 465.6000, 238.4000],
#          [219.2000, 470.4000, 462.4000, 718.4000]]]), 'labels': tensor([[ 2, 15, 15]]), 'image_id': ['000030']}
# 4
# torch.Size([1, 3, 562, 1000])
# {'boxes': tensor([[[154., 206., 364., 748.],
#          [174., 264., 244., 392.],
#          [358., 388., 456., 424.],
#          [376.,  50., 474.,  86.]]]), 'labels': tensor([[ 1,  1, 15, 15]]), 'image_id': ['000032']}
# 3
# torch.Size([1, 3, 600, 820])
# {'boxes': tensor([[[173.7705,  13.1200, 429.5082, 816.7200],
#          [326.2295, 688.8000, 368.8524, 788.8400],
#          [306.5574, 531.3600, 363.9344, 672.4000]]]), 'labels': tensor([[1, 1, 1]]), 'image_id': ['000033']}
# 2
# torch.Size([1, 3, 833, 600])
# {'boxes': tensor([[[276.5560, 191.6667, 664.7340, 598.3333],
#          [253.2320, 233.3333, 379.8480, 553.3333]]]), 'labels': tensor([[19, 19]]), 'image_id': ['000034']}
# 4
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[152.0000,   0.0000, 576.0000, 304.0000],
#          [155.2000, 347.2000, 507.2000, 742.4000],
#          [310.4000, 747.2000, 505.6000, 798.4000],
#          [484.8000,   3.2000, 598.4000, 798.4000]]]), 'labels': tensor([[15, 15, 15, 11]]), 'image_id': ['000035']}
# 1
# torch.Size([1, 3, 904, 600])
# {'boxes': tensor([[[141.0240,  46.9880, 620.1440, 574.6988]]]), 'labels': tensor([[12]]), 'image_id': ['000036']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[140.8000, 248.0000, 444.8000, 548.8000]]]), 'labels': tensor([[20]]), 'image_id': ['000039']}
# 3
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 82.8829, 652.3240, 190.9910, 776.6620],
#          [163.9640, 387.4300, 542.3423, 551.4120],
#          [264.8649, 293.7260, 437.8378, 407.2520]]]), 'labels': tensor([[20, 15, 15]]), 'image_id': ['000041']}
# 2
# torch.Size([1, 3, 600, 896])
# {'boxes': tensor([[[ 55.5224, 469.5040, 526.5672, 894.2080],
#          [ 62.6866,   0.0000, 533.7314, 419.3280]]]), 'labels': tensor([[19, 19]]), 'image_id': ['000042']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[  0.0000,   0.0000, 592.7928, 664.9380],
#          [180.1802, 176.5960, 381.9820, 560.4220]]]), 'labels': tensor([[9, 8]]), 'image_id': ['000044']}
# 1
# torch.Size([1, 3, 904, 600])
# {'boxes': tensor([[[421.2640, 379.5181, 659.9200, 571.0844]]]), 'labels': tensor([[3]]), 'image_id': ['000046']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[  0.0000,  25.2280, 560.3604, 825.3160],
#          [304.5045, 789.2760, 412.6126, 875.7720]]]), 'labels': tensor([[7, 9]]), 'image_id': ['000047']}
# 2
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[169.6000,  91.2000, 742.4000, 464.0000],
#          [  0.0000,   1.6000, 798.4000, 481.6000]]]), 'labels': tensor([[ 3, 15]]), 'image_id': ['000048']}
# 10
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[243.2000, 646.4000, 406.4000, 787.2000],
#          [204.8000, 438.4000, 270.4000, 497.6000],
#          [305.6000, 574.4000, 422.4000, 608.0000],
#          [288.0000, 636.8000, 374.4000, 673.6000],
#          [286.4000, 430.4000, 393.6000, 464.0000],
#          [280.0000, 468.8000, 384.0000, 497.6000],
#          [152.0000, 107.2000, 598.4000, 467.2000],
#          [112.0000,   0.0000, 529.6000, 137.6000],
#          [107.2000, 294.4000, 313.6000, 412.8000],
#          [100.8000, 456.0000, 379.2000, 648.0000]]]), 'labels': tensor([[ 9,  9,  5,  5,  5,  5, 15, 15, 15, 15]]), 'image_id': ['000050']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[219.2000, 561.6000, 598.4000, 798.4000],
#          [  0.0000, 166.4000, 390.4000, 681.6000],
#          [ 96.0000, 662.4000, 310.4000, 742.4000]]]), 'labels': tensor([[14, 14, 15]]), 'image_id': ['000051']}
# 6
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[416.2162, 744.2260, 472.0721, 823.5140],
#          [425.2252, 522.5800, 484.6847, 598.2640],
#          [427.0270, 327.9640, 490.0901, 407.2520],
#          [437.8378,  91.9020, 491.8919, 176.5960],
#          [171.1712, 109.9220, 236.0360, 191.0120],
#          [167.5676, 329.7660, 228.8288, 403.6480]]]), 'labels': tensor([[16, 16, 16, 16, 16, 16]]), 'image_id': ['000052']}
# 5
# torch.Size([1, 3, 600, 898])
# {'boxes': tensor([[[244.3114,   0.0000, 596.4072, 765.0960],
#          [109.5808,   0.0000, 420.3593, 858.4880],
#          [ 46.7066,   0.0000, 251.4970, 756.1160],
#          [ 10.7784,  77.2280, 238.9222, 820.7720],
#          [  8.9820, 355.6080, 174.2515, 851.3040]]]), 'labels': tensor([[7, 7, 7, 7, 7]]), 'image_id': ['000060']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 18.0180, 491.9460, 500.9009, 785.6720],
#          [383.7838, 329.7660, 452.2523, 504.5600]]]), 'labels': tensor([[4, 4]]), 'image_id': ['000061']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[182.4000, 195.2000, 438.4000, 604.8000],
#          [  0.0000, 118.4000, 598.4000, 683.2000]]]), 'labels': tensor([[12,  9]]), 'image_id': ['000063']}
# 1
# torch.Size([1, 3, 605, 600])
# {'boxes': tensor([[[ 26.6200,   0.0000, 603.7900, 544.3549]]]), 'labels': tensor([[3]]), 'image_id': ['000064']}
# 1
# torch.Size([1, 3, 600, 896])
# {'boxes': tensor([[[184.4776,   1.7920, 596.4179, 711.4240]]]), 'labels': tensor([[12]]), 'image_id': ['000065']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[297.6000, 332.8000, 366.4000, 363.2000],
#          [289.6000, 385.6000, 412.8000, 436.8000],
#          [299.2000, 428.8000, 412.8000, 470.4000]]]), 'labels': tensor([[15, 15, 15]]), 'image_id': ['000066']}
# 2
# torch.Size([1, 3, 901, 600])
# {'boxes': tensor([[[126.1400,  70.2703, 850.5440, 598.1982],
#          [ 73.8820,  57.6577, 243.2700, 594.5946]]]), 'labels': tensor([[14, 14]]), 'image_id': ['000072']}
# 4
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[227.2000, 192.0000, 734.4000, 598.4000],
#          [244.8000,   1.6000, 732.8000, 100.8000],
#          [246.4000, 430.4000, 528.0000, 598.4000],
#          [227.2000,  33.6000, 798.4000, 232.0000]]]), 'labels': tensor([[16, 16,  4, 15]]), 'image_id': ['000073']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[  0.0000, 430.6780, 598.1982, 899.1980],
#          [  0.0000,   1.8020, 598.1982, 549.6100]]]), 'labels': tensor([[8, 8]]), 'image_id': ['000077']}
# 2
# torch.Size([1, 3, 600, 716])
# {'boxes': tensor([[[105.9666,  20.0480, 588.5441, 678.7680],
#          [ 57.2792, 133.1760, 339.3795, 624.3520]]]), 'labels': tensor([[12, 12]]), 'image_id': ['000078']}
# 9
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[282.8829, 421.6680, 506.3063, 830.7220],
#          [297.2973,  12.6140, 578.3784, 394.6380],
#          [279.2793, 354.9940, 414.4144, 612.6800],
#          [259.4595, 627.0960, 477.4775, 810.9000],
#          [290.0901, 108.1200, 598.1982, 304.5380],
#          [297.2973,  50.4560, 381.9820, 129.7440],
#          [441.4414, 535.1940, 598.1982, 778.4640],
#          [385.5856, 351.3900, 592.7928, 596.4620],
#          [535.1351, 484.7380, 598.1982, 582.0460]]]), 'labels': tensor([[18, 18, 15, 15, 15, 15, 15, 15, 15]]), 'image_id': ['000081']}
# 6
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 57.6577, 194.6160, 554.9550, 803.6920],
#          [  1.8018, 682.9580, 241.4414, 782.0680],
#          [ 23.4234, 246.8740, 205.4054, 345.9840],
#          [ 34.2342,   0.0000, 365.7658, 133.3480],
#          [ 84.6847, 106.3180, 279.2793, 203.6260],
#          [ 90.0901,  55.8620, 290.0901, 147.7640]]]), 'labels': tensor([[ 7, 15, 15, 15, 15, 15]]), 'image_id': ['000083']}
# 4
# torch.Size([1, 3, 600, 802])
# {'boxes': tensor([[[  9.6257,  30.4760, 567.9144, 291.9280],
#          [343.3155, 155.5880, 598.3958, 686.5120],
#          [222.9947, 530.9240, 585.5615, 728.2160],
#          [ 80.2139,  33.6840, 465.2406, 506.8640]]]), 'labels': tensor([[15, 15, 15,  9]]), 'image_id': ['000089']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[384.0000, 198.4000, 452.8000, 310.4000],
#          [395.2000, 128.0000, 427.2000, 166.4000],
#          [398.4000, 144.0000, 436.8000, 200.0000]]]), 'labels': tensor([[7, 7, 7]]), 'image_id': ['000091']}
# 2
# torch.Size([1, 3, 600, 885])
# {'boxes': tensor([[[219.4690, 307.9800, 447.7876, 607.1100],
#          [  3.5398,  92.0400, 596.4602, 883.2300]]]), 'labels': tensor([[12,  9]]), 'image_id': ['000093']}
# 2
# torch.Size([1, 3, 600, 929])
# {'boxes': tensor([[[ 94.7368,  35.3020, 527.5542, 813.8040],
#          [230.3406,   0.0000, 432.8174, 209.9540]]]), 'labels': tensor([[19, 19]]), 'image_id': ['000095']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[121.6000,   4.8000, 401.6000, 510.4000]]]), 'labels': tensor([[8]]), 'image_id': ['000099']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[102.7027, 331.5680, 333.3333, 625.2940],
#          [113.5135,  70.2780, 598.1982, 718.9980]]]), 'labels': tensor([[ 9, 15]]), 'image_id': ['000101']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[278.4000, 664.0000, 500.8000, 798.4000],
#          [212.8000, 192.0000, 436.8000, 561.6000]]]), 'labels': tensor([[18, 18]]), 'image_id': ['000102']}
# 3
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[196.3964, 724.4040, 475.6757, 899.1980],
#          [133.3333, 522.5800, 598.1982, 794.6820],
#          [ 10.8108,   1.8020, 598.1982, 508.1640]]]), 'labels': tensor([[20, 15, 15]]), 'image_id': ['000104']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[276.8000, 752.0000, 361.6000, 798.4000],
#          [236.8000, 472.0000, 283.2000, 532.8000],
#          [232.0000, 385.6000, 268.8000, 412.8000]]]), 'labels': tensor([[17, 10, 17]]), 'image_id': ['000107']}
# 1
# torch.Size([1, 3, 508, 1000])
# {'boxes': tensor([[[ 22.,  32., 468., 962.]]]), 'labels': tensor([[3]]), 'image_id': ['000109']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[371.2000, 124.8000, 500.8000, 174.4000],
#          [368.0000,  84.8000, 548.8000, 136.0000],
#          [371.2000,  48.0000, 483.2000,  78.4000]]]), 'labels': tensor([[15, 15, 15]]), 'image_id': ['000110']}
# 2
# torch.Size([1, 3, 901, 600])
# {'boxes': tensor([[[311.7460, 124.3243, 589.2540, 497.2973],
#          [290.1220, 515.3153, 354.9940, 567.5676]]]), 'labels': tensor([[12,  9]]), 'image_id': ['000112']}
# 1
# torch.Size([1, 3, 600, 904])
# {'boxes': tensor([[[180.7229, 499.0080, 468.0723, 638.2240]]]), 'labels': tensor([[15]]), 'image_id': ['000113']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 73.8739,   0.0000, 509.9099, 895.5940]]]), 'labels': tensor([[1]]), 'image_id': ['000117']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[153.6000, 260.8000, 598.4000, 448.0000]]]), 'labels': tensor([[8]]), 'image_id': ['000118']}
# 1
# torch.Size([1, 3, 600, 750])
# {'boxes': tensor([[[180.0000,  97.5000, 412.5000, 658.5000]]]), 'labels': tensor([[12]]), 'image_id': ['000120']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 43.2000, 400.0000, 425.6000, 758.4000],
#          [ 43.2000,  33.6000, 435.2000, 400.0000]]]), 'labels': tensor([[20, 20]]), 'image_id': ['000121']}
# 1
# torch.Size([1, 3, 606, 600])
# {'boxes': tensor([[[ 23.9875,  44.2105, 597.1625, 541.8947]]]), 'labels': tensor([[8]]), 'image_id': ['000122']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 40.0000,   0.0000, 542.4000, 571.2000]]]), 'labels': tensor([[19]]), 'image_id': ['000123']}
# 4
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[347.2000, 678.4000, 438.4000, 798.4000],
#          [299.2000, 696.0000, 355.2000, 745.6000],
#          [332.8000, 609.6000, 433.6000, 662.4000],
#          [339.2000, 563.2000, 440.0000, 611.2000]]]), 'labels': tensor([[ 2, 15, 15, 15]]), 'image_id': ['000125']}
# 6
# torch.Size([1, 3, 898, 600])
# {'boxes': tensor([[[360.9960, 123.9521, 896.2040, 456.2874],
#          [432.8360, 449.1018, 896.2040, 598.2036],
#          [256.8280,   0.0000, 781.2600, 118.5629],
#          [  0.0000,   0.0000, 650.1520, 116.7665],
#          [  0.0000, 131.1377, 827.9560, 486.8264],
#          [ 32.3280, 450.8982, 872.8560, 598.2036]]]), 'labels': tensor([[ 2,  2,  2, 15, 15, 15]]), 'image_id': ['000129']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  0.0000,   4.8000, 396.8000, 798.4000]]]), 'labels': tensor([[4]]), 'image_id': ['000130']}
# 3
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[176.5766,   0.0000, 477.4775, 854.1480],
#          [223.4234, 221.6460, 273.8739, 308.1420],
#          [216.2162, 329.7660, 275.6757, 405.4500]]]), 'labels': tensor([[ 7, 15, 15]]), 'image_id': ['000131']}
# 1
# torch.Size([1, 3, 600, 713])
# {'boxes': tensor([[[ 92.6366,  59.8920, 515.9145, 396.4280]]]), 'labels': tensor([[6]]), 'image_id': ['000132']}
# 4
# torch.Size([1, 3, 671, 600])
# {'boxes': tensor([[[ 22.8140,  96.6443, 669.6580, 543.6242],
#          [303.2920, 179.8658, 669.6580, 452.3490],
#          [  0.0000,  28.1879, 134.2000,  99.3289],
#          [ 76.4940,  55.0336, 138.2260, 182.5503]]]), 'labels': tensor([[15, 13, 15, 13]]), 'image_id': ['000133']}
# 1
# torch.Size([1, 3, 600, 809])
# {'boxes': tensor([[[184.3666,   0.0000, 532.0755, 786.3480]]]), 'labels': tensor([[7]]), 'image_id': ['000134']}
# 4
# torch.Size([1, 3, 600, 904])
# {'boxes': tensor([[[ 99.3976,   9.0400, 513.2530, 276.6240],
#          [103.0120, 260.3520, 464.4578, 509.8560],
#          [ 95.7831, 403.1840, 598.1927, 793.7120],
#          [171.6868, 654.4960, 598.1927, 902.1920]]]), 'labels': tensor([[15, 15, 15, 15]]), 'image_id': ['000138']}
# 2
# torch.Size([1, 3, 600, 748])
# {'boxes': tensor([[[216.9576, 158.5760, 447.3815, 575.9600],
#          [167.5810,   1.4960, 598.5037, 746.5040]]]), 'labels': tensor([[12, 18]]), 'image_id': ['000140']}
# 1
# torch.Size([1, 3, 600, 709])
# {'boxes': tensor([[[ 73.7589,  34.0320, 564.5390, 591.3060]]]), 'labels': tensor([[3]]), 'image_id': ['000141']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[128.0000,  40.0000, 424.0000, 742.4000]]]), 'labels': tensor([[7]]), 'image_id': ['000142']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 81.0811, 304.5380, 598.1982, 899.1980]]]), 'labels': tensor([[8]]), 'image_id': ['000143']}
# 1
# torch.Size([1, 3, 802, 600])
# {'boxes': tensor([[[332.0280, 247.0588, 652.8280, 402.6738]]]), 'labels': tensor([[15]]), 'image_id': ['000146']}
# 7
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[187.3874,  57.6640, 261.2613, 115.3280],
#          [203.6036, 136.9520, 266.6667, 203.6260],
#          [223.4234, 261.2900, 268.4685, 313.5480],
#          [236.0360, 407.2520, 275.6757, 443.2920],
#          [227.0270, 542.4020, 273.8739, 587.4520],
#          [216.2162, 670.3440, 273.8739, 722.6020],
#          [200.0000, 782.0680, 266.6667, 836.1281]]]), 'labels': tensor([[9, 9, 9, 9, 9, 9, 9]]), 'image_id': ['000147']}
# 5
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[138.7387, 333.3700, 473.8739, 573.0360],
#          [ 95.4955, 634.3040, 192.7928, 681.1560],
#          [ 90.0901, 746.0280, 194.5946, 783.8700],
#          [ 95.4955, 855.9500, 174.7748, 884.7820],
#          [ 90.0901, 879.3760, 178.3784, 899.1980]]]), 'labels': tensor([[13, 15, 15, 15, 15]]), 'image_id': ['000150']}
# 4
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[233.6000, 377.6000, 304.0000, 571.2000],
#          [ 88.0000, 219.2000, 110.4000, 264.0000],
#          [180.8000,  73.6000, 198.4000, 187.2000],
#          [172.8000,   3.2000, 193.6000, 100.8000]]]), 'labels': tensor([[7, 7, 7, 7]]), 'image_id': ['000153']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[135.1351, 104.5160, 477.4775, 659.5320],
#          [345.9460, 792.8800, 381.9820, 823.5140]]]), 'labels': tensor([[4, 4]]), 'image_id': ['000154']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[115.2000,  64.0000, 561.6000, 608.0000],
#          [163.2000, 689.6000, 228.8000, 792.0000],
#          [180.8000, 644.8000, 227.2000, 694.4000]]]), 'labels': tensor([[18,  7,  7]]), 'image_id': ['000156']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[131.2000, 312.0000, 329.6000, 425.6000]]]), 'labels': tensor([[3]]), 'image_id': ['000158']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 84.6847, 419.8660, 221.6216, 513.5700],
#          [ 27.0270,   0.0000, 598.1982, 895.5940]]]), 'labels': tensor([[15,  7]]), 'image_id': ['000159']}
# 2
# torch.Size([1, 3, 600, 769])
# {'boxes': tensor([[[ 50.7692, 158.4140, 598.4615, 684.4100],
#          [298.4615, 103.0460, 441.5385, 184.5600]]]), 'labels': tensor([[7, 7]]), 'image_id': ['000161']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[361.6000, 488.0000, 476.8000, 606.4000],
#          [227.2000, 312.0000, 588.8000, 492.8000]]]), 'labels': tensor([[20, 15]]), 'image_id': ['000162']}
# 2
# torch.Size([1, 3, 600, 694])
# {'boxes': tensor([[[ 29.1667,  70.7880, 454.1667, 426.1160],
#          [148.6111,  34.7000, 548.6111, 631.5400]]]), 'labels': tensor([[15, 14]]), 'image_id': ['000163']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[244.8000, 180.8000, 555.2000, 588.8000],
#          [ 76.8000, 465.6000, 590.4000, 712.0000]]]), 'labels': tensor([[14, 15]]), 'image_id': ['000164']}
# 1
# torch.Size([1, 3, 600, 777])
# {'boxes': tensor([[[ 82.3834, 136.7520, 598.4456, 775.4460]]]), 'labels': tensor([[15]]), 'image_id': ['000165']}
# 6
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 48.6486,  39.6440, 509.9099, 863.1580],
#          [  3.6036, 182.0020,  88.2883, 288.3200],
#          [ 39.6396, 789.2760, 318.9189, 899.1980],
#          [ 68.4685, 753.2360, 144.1441, 798.2860],
#          [ 63.0631, 816.3060, 126.1261, 875.7720],
#          [ 81.0811,  19.8220, 236.0360, 185.6060]]]), 'labels': tensor([[ 7, 15,  7, 15, 15,  7]]), 'image_id': ['000169']}
# 6
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[158.4000, 137.6000, 262.4000, 172.8000],
#          [180.8000,  64.0000, 288.0000, 115.2000],
#          [235.2000, 516.8000, 328.0000, 561.6000],
#          [249.6000, 680.0000, 310.4000, 707.2000],
#          [144.0000,   3.2000, 328.0000,  67.2000],
#          [ 43.2000,   4.8000, 593.6000, 736.0000]]]), 'labels': tensor([[ 5,  5,  5,  5, 15, 15]]), 'image_id': ['000170']}
# 2
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[462.4000,   0.0000, 649.6000, 203.2000],
#          [ 32.0000, 148.8000, 784.0000, 598.4000]]]), 'labels': tensor([[12, 15]]), 'image_id': ['000171']}
# 2
# torch.Size([1, 3, 731, 600])
# {'boxes': tensor([[[ 95.9437, 159.8985, 450.7833, 409.6447],
#          [ 95.9437, 164.4670, 705.1104, 437.0558]]]), 'labels': tensor([[15, 13]]), 'image_id': ['000173']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[  7.2072, 255.8840, 598.1982, 765.8500]]]), 'labels': tensor([[15]]), 'image_id': ['000174']}
# 9
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[241.6000,  92.8000, 598.4000, 736.0000],
#          [238.4000, 548.8000, 598.4000, 798.4000],
#          [134.4000, 512.0000, 577.6000, 728.0000],
#          [145.6000, 484.8000, 332.8000, 624.0000],
#          [139.2000, 446.4000, 273.6000, 537.6000],
#          [105.6000, 259.2000, 259.2000, 416.0000],
#          [148.8000, 198.4000, 264.0000, 260.8000],
#          [137.6000, 118.4000, 368.0000, 251.2000],
#          [177.6000,   0.0000, 598.4000, 153.6000]]]), 'labels': tensor([[11, 15, 15, 15, 15, 15, 15, 15, 15]]), 'image_id': ['000177']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[174.4000,  20.8000, 568.0000, 792.0000]]]), 'labels': tensor([[7]]), 'image_id': ['000180']}
# 4
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[168.0000, 460.8000, 305.6000, 539.2000],
#          [228.8000, 598.4000, 299.2000, 643.2000],
#          [244.8000, 731.2000, 302.4000, 766.4000],
#          [  0.0000,   1.6000, 598.4000, 497.6000]]]), 'labels': tensor([[4, 4, 4, 4]]), 'image_id': ['000184']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[150.4000,   0.0000, 536.0000, 382.4000]]]), 'labels': tensor([[20]]), 'image_id': ['000187']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 60.8000, 102.4000, 552.0000, 732.8000]]]), 'labels': tensor([[3]]), 'image_id': ['000189']}
# 13
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[313.6000, 680.0000, 435.2000, 798.4000],
#          [344.0000, 374.4000, 411.2000, 515.2000],
#          [337.6000, 224.0000, 440.0000, 268.8000],
#          [334.4000,  80.0000, 491.2000, 241.6000],
#          [332.8000,   0.0000, 499.2000,  86.4000],
#          [384.0000, 500.8000, 428.8000, 518.4000],
#          [385.6000, 443.2000, 427.2000, 452.8000],
#          [390.4000, 435.2000, 409.6000, 443.2000],
#          [385.6000, 408.0000, 430.4000, 422.4000],
#          [388.8000, 393.6000, 427.2000, 408.0000],
#          [390.4000, 328.0000, 430.4000, 340.8000],
#          [387.2000, 297.6000, 441.6000, 312.0000],
#          [390.4000, 283.2000, 435.2000, 294.4000]]]), 'labels': tensor([[ 6,  6,  6,  6,  6, 15, 15, 15, 15, 15, 15, 15, 15]]), 'image_id': ['000190']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[100.8000, 184.0000, 598.4000, 568.0000],
#          [337.6000,   1.6000, 598.4000,  76.8000]]]), 'labels': tensor([[15,  9]]), 'image_id': ['000192']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  4.8000, 126.4000, 598.4000, 798.4000],
#          [ 44.8000,   0.0000, 598.4000, 361.6000],
#          [198.4000,   1.6000, 598.4000, 798.4000]]]), 'labels': tensor([[15, 15, 18]]), 'image_id': ['000193']}
# 3
# torch.Size([1, 3, 600, 857])
# {'boxes': tensor([[[ 93.7500, 227.6406, 597.3214, 637.3937],
#          [ 48.2143, 305.3062, 361.6071, 540.9812],
#          [203.5714, 744.5187, 350.8929, 795.4031]]]), 'labels': tensor([[13, 15, 15]]), 'image_id': ['000194']}
# 1
# torch.Size([1, 3, 600, 896])
# {'boxes': tensor([[[238.2090, 284.9280, 426.2687, 510.7200]]]), 'labels': tensor([[19]]), 'image_id': ['000198']}
# 7
# torch.Size([1, 3, 498, 1000])
# {'boxes': tensor([[[ 36.,  54., 332., 204.],
#          [106.,  30., 496., 354.],
#          [ 44., 292., 496., 488.],
#          [ 36., 452., 496., 798.],
#          [ 24., 780., 496., 998.],
#          [422., 726., 496., 776.],
#          [288., 460., 418., 518.]]]), 'labels': tensor([[15, 15, 15, 15, 15,  5,  5]]), 'image_id': ['000200']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[297.2973,  91.9020, 596.3964, 299.1320]]]), 'labels': tensor([[9]]), 'image_id': ['000203']}
# 1
# torch.Size([1, 3, 898, 600])
# {'boxes': tensor([[[366.3840,   0.0000, 572.9240, 201.1976]]]), 'labels': tensor([[6]]), 'image_id': ['000207']}
# 6
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[203.2000,   0.0000, 416.0000, 264.0000],
#          [355.2000, 526.4000, 598.4000, 798.4000],
#          [180.8000, 185.6000, 348.8000, 286.4000],
#          [193.6000,  92.8000, 406.4000, 208.0000],
#          [292.8000,   0.0000, 390.4000,  51.2000],
#          [240.0000, 323.2000, 491.2000, 696.0000]]]), 'labels': tensor([[11,  9,  9,  9,  9, 18]]), 'image_id': ['000208']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[120.0000,  20.8000, 598.4000, 638.4000]]]), 'labels': tensor([[8]]), 'image_id': ['000209']}
# 4
# torch.Size([1, 3, 600, 802])
# {'boxes': tensor([[[336.8984, 603.1040, 359.3583, 646.4120],
#          [336.8984, 708.9680, 375.4011, 749.0680],
#          [341.7112, 516.4880, 360.9626, 535.7360],
#          [341.7112,  22.4560, 383.4225,  57.7440]]]), 'labels': tensor([[ 7, 15, 15, 15]]), 'image_id': ['000210']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[417.6000,  75.2000, 556.8000, 388.8000]]]), 'labels': tensor([[10]]), 'image_id': ['000211']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  0.0000, 326.4000, 598.4000, 798.4000]]]), 'labels': tensor([[13]]), 'image_id': ['000214']}
# 1
# torch.Size([1, 3, 600, 641])
# {'boxes': tensor([[[102.5641, 183.3260, 525.6411, 432.0340]]]), 'labels': tensor([[8]]), 'image_id': ['000215']}
# 3
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[113.5135, 454.1040, 457.6577, 688.3640],
#          [  0.0000, 191.0120, 311.7117, 362.2020],
#          [  0.0000,   0.0000, 398.1982, 454.1040]]]), 'labels': tensor([[12,  9, 15]]), 'image_id': ['000218']}
# 1
# torch.Size([1, 3, 901, 600])
# {'boxes': tensor([[[598.2640, 214.4144, 834.3260, 556.7568]]]), 'labels': tensor([[14]]), 'image_id': ['000219']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[201.6000,  62.4000, 465.6000, 740.8000],
#          [180.8000, 681.6000, 265.6000, 798.4000],
#          [233.6000, 422.4000, 297.6000, 497.6000]]]), 'labels': tensor([[ 7,  7, 15]]), 'image_id': ['000220']}
# 1
# torch.Size([1, 3, 600, 904])
# {'boxes': tensor([[[137.3494, 128.3680, 455.4217, 779.2480]]]), 'labels': tensor([[7]]), 'image_id': ['000221']}
# 15
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[344.0000, 283.2000, 520.0000, 483.2000],
#          [377.6000, 398.4000, 598.4000, 577.6000],
#          [376.0000, 180.8000, 598.4000, 361.6000],
#          [355.2000, 352.0000, 424.0000, 374.4000],
#          [339.2000, 372.8000, 408.0000, 390.4000],
#          [236.8000, 544.0000, 344.0000, 600.0000],
#          [304.0000, 251.2000, 352.0000, 294.4000],
#          [281.6000, 252.8000, 366.4000, 328.0000],
#          [283.2000, 401.6000, 363.2000, 496.0000],
#          [307.2000, 464.0000, 384.0000, 529.6000],
#          [332.8000, 507.2000, 526.4000, 595.2000],
#          [328.0000, 158.4000, 545.6000, 270.4000],
#          [451.2000, 708.8000, 598.4000, 798.4000],
#          [387.2000, 584.0000, 598.4000, 628.8000],
#          [345.6000, 585.6000, 428.8000, 622.4000]]]), 'labels': tensor([[11, 15, 15,  5,  5, 15, 15, 15, 15, 15, 15, 15, 15,  9,  9]]), 'image_id': ['000222']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[252.8000,  56.0000, 537.6000, 350.4000],
#          [390.4000, 640.0000, 598.4000, 798.4000]]]), 'labels': tensor([[20,  5]]), 'image_id': ['000224']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[171.1712, 223.4480, 472.0721, 637.9080],
#          [ 37.8378,   1.8020, 144.1441,  82.8920]]]), 'labels': tensor([[17, 17]]), 'image_id': ['000225']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[145.9460, 163.9820, 409.0090, 564.0260]]]), 'labels': tensor([[1]]), 'image_id': ['000228']}
# 11
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[332.8000, 150.4000, 598.4000, 672.0000],
#          [348.8000, 636.8000, 592.0000, 776.0000],
#          [256.0000, 544.0000, 475.2000, 689.6000],
#          [214.4000, 612.8000, 323.2000, 697.6000],
#          [208.0000, 380.8000, 336.0000, 537.6000],
#          [228.8000, 235.2000, 406.4000, 336.0000],
#          [254.4000, 128.0000, 521.6000, 313.6000],
#          [299.2000,   1.6000, 598.4000, 169.6000],
#          [480.0000, 564.8000, 590.4000, 609.6000],
#          [196.8000,  60.8000, 256.0000,  84.8000],
#          [300.8000, 736.0000, 449.6000, 798.4000]]]), 'labels': tensor([[11, 15, 15, 15, 15, 15, 15, 15,  5,  5,  9]]), 'image_id': ['000229']}
# 5
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[145.6000,  73.6000, 532.8000, 600.0000],
#          [ 49.6000, 366.4000, 147.2000, 401.6000],
#          [112.0000, 644.8000, 188.8000, 798.4000],
#          [ 76.8000,   0.0000, 145.6000, 139.2000],
#          [107.2000,  86.4000, 142.4000, 200.0000]]]), 'labels': tensor([[10, 15,  4,  4,  4]]), 'image_id': ['000232']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[168.0000, 441.6000, 425.6000, 771.2000],
#          [  1.6000,   0.0000, 307.2000, 720.0000]]]), 'labels': tensor([[17,  7]]), 'image_id': ['000233']}
# 7
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[406.4000, 387.2000, 598.4000, 504.0000],
#          [520.0000, 216.0000, 598.4000, 432.0000],
#          [464.0000,   0.0000, 596.8000, 153.6000],
#          [390.4000, 641.6000, 504.0000, 726.4000],
#          [424.0000,  62.4000, 598.4000, 441.6000],
#          [305.6000, 662.4000, 404.8000, 729.6000],
#          [265.6000, 294.4000, 376.0000, 320.0000]]]), 'labels': tensor([[ 9,  9,  9,  9, 11, 18, 16]]), 'image_id': ['000235']}
# 1
# torch.Size([1, 3, 600, 787])
# {'boxes': tensor([[[264.5669, 136.9380, 492.9134, 431.2760]]]), 'labels': tensor([[3]]), 'image_id': ['000236']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[291.2000, 568.0000, 446.4000, 798.4000],
#          [172.8000,  94.4000, 339.2000, 225.6000],
#          [212.8000, 392.0000, 345.6000, 555.2000]]]), 'labels': tensor([[4, 4, 4]]), 'image_id': ['000241']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[  3.6036,   3.6040, 515.3153, 897.3960]]]), 'labels': tensor([[8]]), 'image_id': ['000242']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[362.1622, 207.2300, 412.6126, 281.1120]]]), 'labels': tensor([[17]]), 'image_id': ['000244']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[208.0000,  27.2000, 465.6000, 779.2000],
#          [220.8000, 483.2000, 272.0000, 524.8000]]]), 'labels': tensor([[ 7, 15]]), 'image_id': ['000245']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 68.8000,  94.4000, 494.4000, 528.0000]]]), 'labels': tensor([[12]]), 'image_id': ['000246']}
# 8
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[336.9370, 118.9320, 592.7928, 327.9640],
#          [311.7117, 192.8140, 367.5676, 286.5180],
#          [302.7027, 279.3100, 349.5496, 362.2020],
#          [329.7297, 309.9440, 585.5856, 491.9460],
#          [326.1261, 481.1340, 551.3514, 567.6300],
#          [286.4865, 482.9360, 333.3333, 564.0260],
#          [212.6126, 551.4120, 409.0090, 675.7500],
#          [317.1171, 182.0020, 542.3423, 582.0460]]]), 'labels': tensor([[ 9,  9,  9,  9,  9,  9,  9, 11]]), 'image_id': ['000249']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[270.4000,   0.0000, 598.4000, 756.8000],
#          [196.8000, 153.6000, 473.6000, 238.4000]]]), 'labels': tensor([[11,  5]]), 'image_id': ['000250']}
# 7
# torch.Size([1, 3, 662, 600])
# {'boxes': tensor([[[626.2520,   0.0000, 660.6760, 196.0265],
#          [594.4760,   1.3245, 627.5760, 108.6093],
#          [574.6160, 125.8278, 660.6760, 362.9139],
#          [581.2360, 478.1457, 660.6760, 598.6755],
#          [566.6720,  67.5497, 619.6320,  91.3907],
#          [556.0800,  15.8940, 594.4760,  37.0861],
#          [566.6720,  26.4901, 609.0400,  50.3311]]]), 'labels': tensor([[ 7,  7,  7,  7, 15, 15, 15]]), 'image_id': ['000251']}
# 1
# torch.Size([1, 3, 600, 875])
# {'boxes': tensor([[[166.1808,  12.2500, 404.0816, 857.5000]]]), 'labels': tensor([[1]]), 'image_id': ['000256']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  0.0000, 129.6000,  89.6000, 291.2000],
#          [225.6000,  30.4000, 598.4000, 353.6000],
#          [107.2000, 278.4000, 598.4000, 753.6000]]]), 'labels': tensor([[20, 15, 15]]), 'image_id': ['000257']}
# 2
# torch.Size([1, 3, 600, 829])
# {'boxes': tensor([[[  0.0000, 281.8600, 596.6851, 825.6840],
#          [  0.0000,   3.3160, 435.9116, 447.6600]]]), 'labels': tensor([[15, 15]]), 'image_id': ['000259']}
# 1
# torch.Size([1, 3, 392, 1000])
# {'boxes': tensor([[[190., 684., 390., 998.]]]), 'labels': tensor([[7]]), 'image_id': ['000262']}
# 2
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[356.8000,  28.8000, 515.2000, 566.4000],
#          [566.4000,   0.0000, 796.8000, 108.8000]]]), 'labels': tensor([[7, 7]]), 'image_id': ['000263']}
# 2
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[ 28.8000, 155.2000, 798.4000, 596.8000],
#          [  0.0000,   0.0000, 798.4000, 598.4000]]]), 'labels': tensor([[12, 18]]), 'image_id': ['000266']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[183.7838, 322.5580, 504.5045, 783.8700],
#          [102.7027,   0.0000, 598.1982, 470.3220]]]), 'labels': tensor([[1, 1]]), 'image_id': ['000268']}
# 10
# torch.Size([1, 3, 600, 904])
# {'boxes': tensor([[[475.3012, 332.6720, 576.5060, 368.8320],
#          [440.9639, 536.9760, 562.0482, 587.6000],
#          [  0.0000, 432.1120,  45.1807, 470.0800],
#          [  0.0000, 282.0480,  46.9880, 312.7840],
#          [  0.0000, 249.5040,  48.7952, 278.4320],
#          [ 99.3976, 408.6080, 383.1325, 896.7680],
#          [104.8193, 162.7200, 469.8795, 441.1520],
#          [240.3615,  65.0880, 598.1927, 365.2160],
#          [133.7349, 406.8000, 493.3735, 744.8960],
#          [204.2169, 464.6560, 598.1927, 860.6080]]]), 'labels': tensor([[ 5,  5,  5,  5,  5, 15, 15, 15, 15, 15]]), 'image_id': ['000269']}
# 1
# torch.Size([1, 3, 600, 929])
# {'boxes': tensor([[[221.0526, 276.8420, 338.0805, 821.2360]]]), 'labels': tensor([[19]]), 'image_id': ['000270']}
# 2
# torch.Size([1, 3, 605, 600])
# {'boxes': tensor([[[ 61.7604, 255.8824, 378.1250, 426.0504],
#          [136.1250,  70.5882, 544.5000, 525.6302]]]), 'labels': tensor([[15, 13]]), 'image_id': ['000275']}
# 3
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[259.2000, 204.8000, 508.8000, 366.4000],
#          [595.2000, 257.6000, 798.4000, 414.4000],
#          [595.2000,  49.6000, 798.4000, 222.4000]]]), 'labels': tensor([[15, 15, 15]]), 'image_id': ['000276']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[248.0000, 468.8000, 598.4000, 798.4000],
#          [140.8000, 176.0000, 598.4000, 665.6000]]]), 'labels': tensor([[12, 15]]), 'image_id': ['000278']}
# 5
# torch.Size([1, 3, 600, 802])
# {'boxes': tensor([[[420.3209, 535.7360, 596.7914, 774.7320],
#          [165.2406, 522.9040, 479.6791, 761.9000],
#          [ 89.8396, 370.5240, 598.3958, 571.0240],
#          [ 49.7326,   3.2080, 598.3958, 317.5920],
#          [221.3904,  91.4280, 598.3958, 473.1800]]]), 'labels': tensor([[ 9, 15, 15, 15, 15]]), 'image_id': ['000282']}
# 4
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[121.6000, 356.8000, 598.4000, 737.6000],
#          [153.6000,  57.6000, 598.4000, 368.0000],
#          [323.2000, 588.8000, 598.4000, 697.6000],
#          [350.4000, 190.4000, 598.4000, 364.8000]]]), 'labels': tensor([[15, 15,  9,  9]]), 'image_id': ['000285']}
# 12
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[311.7117, 872.1680, 502.7027, 899.1980],
#          [291.8919, 796.4840, 508.1081, 861.3560],
#          [273.8739, 753.2360, 430.6306, 789.2760],
#          [279.2793, 791.0780, 412.6126, 809.0980],
#          [291.8919, 740.6220, 445.0450, 773.0580],
#          [347.7477, 731.6120, 450.4504, 758.6420],
#          [281.0811, 670.3440, 477.4775, 720.8000],
#          [302.7027, 592.8580, 452.2523, 682.9580],
#          [273.8739,   0.0000, 547.7477,  34.2380],
#          [196.3964,   0.0000, 437.8378,  57.6640],
#          [254.0540,  52.2580, 367.5676, 136.9520],
#          [ 36.0360, 118.9320, 499.0991, 686.5620]]]), 'labels': tensor([[15, 15, 15, 15, 15, 15, 15, 15, 15, 15,  7,  6]]), 'image_id': ['000288']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[176.5766,  86.4960, 414.4144, 605.4720]]]), 'labels': tensor([[7]]), 'image_id': ['000289']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 16.0000, 526.4000, 587.2000, 724.8000],
#          [147.2000,  86.4000, 592.0000, 265.6000]]]), 'labels': tensor([[3, 3]]), 'image_id': ['000294']}
# 2
# torch.Size([1, 3, 600, 862])
# {'boxes': tensor([[[213.7931, 734.4240, 310.3448, 860.2760],
#          [205.1724,  74.1320, 381.0345, 789.5920]]]), 'labels': tensor([[7, 4]]), 'image_id': ['000296']}
# 1
# torch.Size([1, 3, 600, 773])
# {'boxes': tensor([[[ 47.9381, 276.7340, 553.6082, 522.5480]]]), 'labels': tensor([[15]]), 'image_id': ['000298']}
# 7
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[440.0000, 779.2000, 510.4000, 798.4000],
#          [400.0000, 758.4000, 435.2000, 776.0000],
#          [358.4000, 444.8000, 542.4000, 763.2000],
#          [366.4000, 390.4000, 446.4000, 504.0000],
#          [384.0000,   0.0000, 598.4000, 137.6000],
#          [388.8000, 211.2000, 585.6000, 292.8000],
#          [435.2000, 192.0000, 585.6000, 339.2000]]]), 'labels': tensor([[ 7,  7,  7,  7,  7, 15, 14]]), 'image_id': ['000302']}
# 6
# torch.Size([1, 3, 600, 796])
# {'boxes': tensor([[[ 60.4775,  22.2880, 444.0318, 794.4080],
#          [111.4058, 738.6880, 261.0080, 794.4080],
#          [106.6313, 706.8480, 146.4191, 794.4080],
#          [ 98.6737,   0.0000, 178.2493, 146.4640],
#          [127.3210,   1.5920, 206.8966, 133.7280],
#          [175.0663,   0.0000, 310.3448,  79.6000]]]), 'labels': tensor([[7, 7, 7, 7, 7, 7]]), 'image_id': ['000303']}
# 1
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[152.0000, 129.6000, 379.2000, 385.6000]]]), 'labels': tensor([[20]]), 'image_id': ['000304']}
# 2
# torch.Size([1, 3, 901, 600])
# {'boxes': tensor([[[416.2620,  27.0270, 899.1980, 531.5316],
#          [140.5560, 100.9009, 852.3460, 580.1802]]]), 'labels': tensor([[ 2, 15]]), 'image_id': ['000305']}
# 4
# torch.Size([1, 3, 352, 1000])
# {'boxes': tensor([[[ 62., 176., 142., 286.],
#          [ 70., 226., 170., 362.],
#          [ 90., 472., 172., 602.],
#          [ 82., 604., 172., 758.]]]), 'labels': tensor([[10, 10, 10, 10]]), 'image_id': ['000306']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  3.2000,   1.6000, 598.4000, 798.4000],
#          [364.8000,   0.0000, 598.4000,  62.4000]]]), 'labels': tensor([[16, 16]]), 'image_id': ['000307']}
# 6
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[158.4000, 560.0000, 302.4000, 691.2000],
#          [196.8000, 356.8000, 428.8000, 491.2000],
#          [243.2000, 228.8000, 512.0000, 387.2000],
#          [180.8000, 259.2000, 265.6000, 358.4000],
#          [169.6000, 344.0000, 244.8000, 440.0000],
#          [216.0000,  51.2000, 505.6000, 632.0000]]]), 'labels': tensor([[15, 15, 15, 15, 15, 11]]), 'image_id': ['000308']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 65.6000,  73.6000, 564.8000, 691.2000]]]), 'labels': tensor([[7]]), 'image_id': ['000311']}
# 1
# torch.Size([1, 3, 600, 896])
# {'boxes': tensor([[[  1.7910,   3.5840, 596.4179, 894.2080]]]), 'labels': tensor([[19]]), 'image_id': ['000312']}
# 1
# torch.Size([1, 3, 600, 847])
# {'boxes': tensor([[[254.2373, 198.1980, 372.8814, 687.7640]]]), 'labels': tensor([[7]]), 'image_id': ['000317']}
# 2
# torch.Size([1, 3, 600, 906])
# {'boxes': tensor([[[141.3897, 581.6520, 300.9063, 788.2200],
#          [145.0151, 362.4000, 257.4018, 543.6000]]]), 'labels': tensor([[7, 7]]), 'image_id': ['000318']}
# 4
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[ 11.2000, 486.4000,  41.6000, 537.6000],
#          [ 14.4000, 433.6000,  40.0000, 484.8000],
#          [  0.0000, 363.2000,  44.8000, 435.2000],
#          [123.2000,   0.0000, 798.4000, 593.6000]]]), 'labels': tensor([[ 7,  7,  7, 15]]), 'image_id': ['000320']}
# 1
# torch.Size([1, 3, 901, 600])
# {'boxes': tensor([[[299.1320,  77.4775, 823.5140, 446.8468]]]), 'labels': tensor([[15]]), 'image_id': ['000321']}
# 1
# torch.Size([1, 3, 600, 904])
# {'boxes': tensor([[[  1.8072,  21.6960, 598.1927, 846.1440]]]), 'labels': tensor([[15]]), 'image_id': ['000322']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  3.2000, 441.6000, 598.4000, 798.4000],
#          [  3.2000,  17.6000, 598.4000, 486.4000]]]), 'labels': tensor([[15, 15]]), 'image_id': ['000323']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 99.2000, 158.4000, 318.4000, 798.4000]]]), 'labels': tensor([[1]]), 'image_id': ['000325']}
# 8
# torch.Size([1, 3, 600, 904])
# {'boxes': tensor([[[263.8554, 103.0560, 477.1084, 462.8480],
#          [195.1807,   0.0000, 412.0482,  88.5920],
#          [175.3012, 549.6320, 424.6988, 793.7120],
#          [238.5542, 506.2400, 366.8675, 569.5200],
#          [110.2410, 207.9200, 406.6265, 312.7840],
#          [148.1928, 305.5520, 265.6627, 376.0640],
#          [124.6988, 652.6880, 366.8675, 746.7040],
#          [168.0723, 506.2400, 323.4940, 589.4080]]]), 'labels': tensor([[13, 13, 13, 13, 15, 15, 15, 15]]), 'image_id': ['000328']}
# 3
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[378.3784, 522.5800, 418.0180, 571.2340],
#          [394.5946, 392.8360, 425.2252, 432.4800],
#          [380.1802, 464.9160, 401.8018, 491.9460]]]), 'labels': tensor([[7, 7, 7]]), 'image_id': ['000329']}
# 4
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[372.8000, 272.0000, 769.6000, 595.2000],
#          [353.6000,  96.0000, 680.0000, 219.2000],
#          [584.0000,   0.0000, 798.4000,  78.4000],
#          [404.8000, 236.8000, 745.6000, 571.2000]]]), 'labels': tensor([[ 9,  9,  9, 15]]), 'image_id': ['000331']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 88.2883,  95.5060, 470.2703, 511.7680]]]), 'labels': tensor([[13]]), 'image_id': ['000332']}
# 1
# torch.Size([1, 3, 600, 993])
# {'boxes': tensor([[[216.5563,  71.4960, 351.6556, 540.1920]]]), 'labels': tensor([[7]]), 'image_id': ['000334']}
# 1
# torch.Size([1, 3, 600, 698])
# {'boxes': tensor([[[  8.3721,   4.1880, 593.0233, 657.5160]]]), 'labels': tensor([[12]]), 'image_id': ['000336']}
# 10
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[243.2000, 120.0000, 440.0000, 254.4000],
#          [280.0000, 348.8000, 596.8000, 684.8000],
#          [ 44.8000,  44.8000, 176.0000, 107.2000],
#          [  4.8000, 188.8000,  83.2000, 257.6000],
#          [ 43.2000, 179.2000, 208.0000, 265.6000],
#          [ 25.6000, 385.6000, 163.2000, 459.2000],
#          [145.6000, 107.2000, 406.4000, 262.4000],
#          [ 46.4000, 374.4000, 577.6000, 643.2000],
#          [118.4000, 280.0000, 209.6000, 368.0000],
#          [139.2000, 371.2000, 249.6000, 412.8000]]]), 'labels': tensor([[ 2,  2, 15, 15, 15, 15, 15, 15, 15, 15]]), 'image_id': ['000337']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[162.1622, 353.1920, 207.2072, 387.4300],
#          [129.7297, 145.9620, 363.9640, 690.1660]]]), 'labels': tensor([[15,  7]]), 'image_id': ['000338']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[208.0000, 532.8000, 579.2000, 713.6000],
#          [ 59.2000, 113.6000, 406.4000, 296.0000]]]), 'labels': tensor([[3, 3]]), 'image_id': ['000340']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[116.8000,  38.4000, 515.2000, 780.8000]]]), 'labels': tensor([[7]]), 'image_id': ['000343']}
# 1
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[  1.6000, 140.8000, 704.0000, 489.6000]]]), 'labels': tensor([[5]]), 'image_id': ['000344']}
# 1
# torch.Size([1, 3, 600, 783])
# {'boxes': tensor([[[  1.6807, 127.6996, 583.1933, 688.9056]]]), 'labels': tensor([[13]]), 'image_id': ['000347']}
# 6
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[208.0000, 252.8000, 577.6000, 659.2000],
#          [200.0000, 512.0000, 579.2000, 764.8000],
#          [120.0000, 452.8000, 228.8000, 574.4000],
#          [144.0000, 158.4000, 475.2000, 328.0000],
#          [256.0000, 265.6000, 598.4000, 520.0000],
#          [  1.6000,   1.6000, 208.0000, 140.8000]]]), 'labels': tensor([[11,  9,  9,  9,  9, 20]]), 'image_id': ['000349']}
# 5
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[107.2000,  51.2000, 393.6000, 236.8000],
#          [107.2000, 208.0000, 396.8000, 334.4000],
#          [ 92.8000, 315.2000, 452.8000, 492.8000],
#          [131.2000, 468.8000, 598.4000, 798.4000],
#          [158.4000,  17.6000, 598.4000, 798.4000]]]), 'labels': tensor([[15, 15, 15, 15, 18]]), 'image_id': ['000352']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[184.0000, 243.2000, 598.4000, 568.0000]]]), 'labels': tensor([[8]]), 'image_id': ['000354']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 63.0631,  37.8420, 526.1261, 767.6520]]]), 'labels': tensor([[7]]), 'image_id': ['000355']}
# 3
# torch.Size([1, 3, 694, 600])
# {'boxes': tensor([[[367.8200, 363.8889, 663.4640, 537.5000],
#          [ 16.6560,  33.3333, 666.2400, 398.6111],
#          [115.2040,  52.7778, 589.9000, 581.9444]]]), 'labels': tensor([[12, 15,  9]]), 'image_id': ['000359']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 25.2252, 104.5160, 428.8288, 394.6380],
#          [218.0180, 288.3200, 598.1982, 899.1980]]]), 'labels': tensor([[3, 3]]), 'image_id': ['000363']}
# 7
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[196.8000, 361.6000, 422.4000, 432.0000],
#          [193.6000, 528.0000, 564.8000, 622.4000],
#          [291.2000, 628.8000, 542.4000, 673.6000],
#          [198.4000, 454.4000, 542.4000, 520.0000],
#          [292.8000, 686.4000, 364.8000, 798.4000],
#          [406.4000,   1.6000, 598.4000, 798.4000],
#          [104.0000, 276.8000, 422.4000, 470.4000]]]), 'labels': tensor([[ 5,  5,  5,  5,  7,  7, 15]]), 'image_id': ['000367']}
# 2
# torch.Size([1, 3, 600, 802])
# {'boxes': tensor([[[165.2406, 149.1720, 409.0909, 404.2080],
#          [194.1176, 389.7720, 410.6952, 672.0760]]]), 'labels': tensor([[4, 4]]), 'image_id': ['000370']}
# 3
# torch.Size([1, 3, 600, 898])
# {'boxes': tensor([[[ 32.3353, 481.3280, 529.9401, 644.7640],
#          [202.9940, 633.9880, 278.4431, 752.5240],
#          [ 37.7246, 138.2920, 544.3114, 452.5920]]]), 'labels': tensor([[15, 13, 13]]), 'image_id': ['000372']}
# 1
# torch.Size([1, 3, 901, 600])
# {'boxes': tensor([[[616.2840,  32.4324, 814.5040, 572.9730]]]), 'labels': tensor([[7]]), 'image_id': ['000373']}
# 10
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[134.4000,  75.2000, 596.8000, 796.8000],
#          [  1.6000, 198.4000, 548.8000, 504.0000],
#          [  4.8000,  68.8000, 265.6000, 203.2000],
#          [ 48.0000, 502.4000, 177.6000, 561.6000],
#          [ 54.4000, 470.4000, 182.4000, 510.4000],
#          [ 62.4000, 345.6000, 132.8000, 395.2000],
#          [ 67.2000,  32.0000, 201.6000,  80.0000],
#          [ 56.0000, 752.0000, 200.0000, 793.6000],
#          [ 56.0000, 713.6000, 185.6000, 753.6000],
#          [ 64.0000, 576.0000, 163.2000, 596.8000]]]), 'labels': tensor([[14, 15, 15, 15, 15, 15, 15, 15, 15, 15]]), 'image_id': ['000374']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 24.0000,  72.0000, 544.0000, 707.2000]]]), 'labels': tensor([[2]]), 'image_id': ['000379']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[  5.4054,   3.6040, 594.5946, 897.3960]]]), 'labels': tensor([[2]]), 'image_id': ['000380']}
# 5
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[292.8000,   8.0000, 798.4000, 598.4000],
#          [249.6000, 124.8000, 424.0000, 228.8000],
#          [316.8000,   0.0000, 563.2000, 126.4000],
#          [609.6000,   0.0000, 796.8000, 176.0000],
#          [ 11.2000, 246.4000,  57.6000, 276.8000]]]), 'labels': tensor([[11,  9,  9,  9,  5]]), 'image_id': ['000381']}
# 2
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[265.6000,   3.2000, 798.4000, 259.2000],
#          [422.4000, 158.4000, 475.2000, 188.8000]]]), 'labels': tensor([[ 4, 15]]), 'image_id': ['000382']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 30.6306,   7.2080, 457.6577, 866.7620]]]), 'labels': tensor([[7]]), 'image_id': ['000387']}
# 1
# torch.Size([1, 3, 600, 655])
# {'boxes': tensor([[[ 60.2620,  73.3600, 598.6899, 607.8400]]]), 'labels': tensor([[16]]), 'image_id': ['000391']}
# 5
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[300.8000, 312.0000, 598.4000, 798.4000],
#          [134.4000,  44.8000, 598.4000, 403.2000],
#          [ 35.2000,   0.0000, 489.6000, 548.8000],
# ...
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[174.4000, 340.8000, 515.2000, 600.0000],
#          [ 56.0000, 428.8000, 323.2000, 544.0000],
#          [132.8000, 257.6000, 587.2000, 380.8000]]]), 'labels': tensor([[13, 15, 15]]), 'image_id': ['001730']}
# 9
# torch.Size([1, 3, 600, 904])
# {'boxes': tensor([[[307.2289,  57.8560, 404.8193, 211.5360],
#          [256.6265, 309.1680, 339.7590, 435.7280],
#          [251.2048, 404.9920, 287.3494, 466.4640],
#          [216.8675, 453.8080, 254.8193, 535.1680],
#          [187.9518, 457.4240, 234.9398, 574.9440],
#          [164.4578, 524.3200, 211.4458, 612.9120],
#          [220.4819, 589.4080, 285.5422, 685.2320],
#          [269.2771, 665.3440, 352.4096, 797.3280],
#          [343.3735, 627.3760, 520.4819, 800.9440]]]), 'labels': tensor([[4, 4, 4, 4, 4, 4, 4, 4, 4]]), 'image_id': ['001732']}
# 19
# torch.Size([1, 3, 600, 600])
# {'boxes': tensor([[[322.8000,   0.0000, 393.6000,  97.2000],
#          [328.8000, 282.0000, 390.0000, 351.6000],
#          [328.8000, 214.8000, 436.8000, 280.8000],
#          [312.0000, 157.2000, 343.2000, 199.2000],
#          [301.2000, 123.6000, 321.6000, 138.0000],
#          [303.6000,  66.0000, 328.8000,  97.2000],
#          [314.4000,  26.4000, 327.6000,  49.2000],
#          [303.6000,   8.4000, 324.0000,  28.8000],
#          [306.0000,  34.8000, 321.6000,  52.8000],
#          [306.0000, 242.4000, 319.2000, 256.8000],
#          [310.8000, 196.8000, 336.0000, 218.4000],
#          [309.6000, 259.2000, 318.0000, 276.0000],
#          [315.6000, 304.8000, 332.4000, 322.8000],
#          [318.0000, 322.8000, 330.0000, 343.2000],
#          [315.6000, 432.0000, 330.0000, 450.0000],
#          [313.2000, 404.4000, 325.2000, 420.0000],
#          [313.2000, 387.6000, 327.6000, 409.2000],
#          [310.8000, 373.2000, 327.6000, 386.4000],
#          [309.6000, 355.2000, 327.6000, 373.2000]]]), 'labels': tensor([[17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17,
#          17]]), 'image_id': ['001733']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[132.8000, 158.4000, 499.2000, 704.0000]]]), 'labels': tensor([[17]]), 'image_id': ['001734']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[107.2000, 198.4000, 478.4000, 515.2000]]]), 'labels': tensor([[12]]), 'image_id': ['001738']}
# 1
# torch.Size([1, 3, 901, 600])
# {'boxes': tensor([[[318.9540, 266.6667, 569.4320, 383.7838]]]), 'labels': tensor([[3]]), 'image_id': ['001739']}
# 2
# torch.Size([1, 3, 600, 945])
# {'boxes': tensor([[[259.8425,   0.0000, 590.5512, 269.3250],
#          [311.8110, 781.9875, 366.1418, 883.5750]]]), 'labels': tensor([[10, 10]]), 'image_id': ['001741']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[376.0000,   0.0000, 480.0000, 243.2000],
#          [364.8000, 299.2000, 414.4000, 385.6000],
#          [356.8000, 491.2000, 408.0000, 596.8000]]]), 'labels': tensor([[ 7, 18, 18]]), 'image_id': ['001746']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  4.8000, 145.6000, 598.4000, 611.2000]]]), 'labels': tensor([[8]]), 'image_id': ['001747']}
# 1
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[ 40.0000,  36.8000, 795.2000, 531.2000]]]), 'labels': tensor([[15]]), 'image_id': ['001749']}
# 9
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[126.1261, 448.6980, 239.6396, 601.8680],
#          [156.7568, 311.7460, 281.0811, 452.3020],
#          [ 54.0541, 191.0120, 178.3784, 277.5080],
#          [ 27.0270, 722.6020,  93.6937, 834.3260],
#          [331.5315, 459.5100, 446.8468, 618.0860],
#          [336.9370, 308.1420, 446.8468, 459.5100],
#          [392.7928, 610.8780, 488.2883, 728.0080],
#          [396.3964, 726.2060, 497.2973, 839.7320],
#          [378.3784, 205.4280, 490.0901, 281.1120]]]), 'labels': tensor([[17, 17, 17, 17, 17, 17, 17, 17, 17]]), 'image_id': ['001750']}
# 1
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[  4.8000,   3.2000, 798.4000, 598.4000]]]), 'labels': tensor([[20]]), 'image_id': ['001752']}
# 4
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[484.8000, 350.4000, 776.0000, 441.6000],
#          [ 84.8000,  22.4000, 788.8000, 438.4000],
#          [232.0000, 448.0000, 628.8000, 596.8000],
#          [209.6000,   4.8000, 276.8000,  86.4000]]]), 'labels': tensor([[ 5, 15, 15, 16]]), 'image_id': ['001754']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[ 28.8288, 108.1200, 598.1982, 899.1980],
#          [  3.6036, 297.3300, 239.6396, 899.1980]]]), 'labels': tensor([[8, 8]]), 'image_id': ['001755']}
# 6
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[659.2000, 112.0000, 798.4000, 598.4000],
#          [593.6000, 552.0000, 680.0000, 598.4000],
#          [483.2000, 209.6000, 713.6000, 278.4000],
#          [164.8000, 408.0000, 662.4000, 579.2000],
#          [ 51.2000,   6.4000, 723.2000, 417.6000],
#          [707.2000,  40.0000, 798.4000, 169.6000]]]), 'labels': tensor([[11,  9,  5, 15, 15,  9]]), 'image_id': ['001756']}
# 2
# torch.Size([1, 3, 802, 600])
# {'boxes': tensor([[[362.5040, 324.0642, 599.8960, 450.8022],
#          [171.6280,   4.8128, 800.3960, 370.5882]]]), 'labels': tensor([[12, 15]]), 'image_id': ['001758']}
# 4
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[243.2000,   1.6000, 598.4000, 313.6000],
#          [180.8000, 254.4000, 598.4000, 584.0000],
#          [  1.6000, 475.2000, 598.4000, 798.4000],
#          [  3.2000,   0.0000, 288.0000, 478.4000]]]), 'labels': tensor([[12, 15, 15, 15]]), 'image_id': ['001759']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[154.9550,  46.8520, 490.0901, 899.1980]]]), 'labels': tensor([[1]]), 'image_id': ['001761']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  9.6000, 118.4000, 563.2000, 617.6000]]]), 'labels': tensor([[14]]), 'image_id': ['001765']}
# 13
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 43.2000, 628.8000, 155.2000, 673.6000],
#          [ 11.2000, 576.0000, 144.0000, 608.0000],
#          [ 11.2000, 545.6000, 134.4000, 577.6000],
#          [  1.6000, 443.2000, 110.4000, 491.2000],
#          [  0.0000, 398.4000,  91.2000, 432.0000],
#          [113.6000, 185.6000, 281.6000, 299.2000],
#          [132.8000, 353.6000, 275.2000, 430.4000],
#          [382.4000,  41.6000, 524.8000, 156.8000],
#          [492.8000,  88.0000, 598.4000, 200.0000],
#          [160.0000, 288.0000, 459.2000, 537.6000],
#          [137.6000, 176.0000, 412.8000, 339.2000],
#          [380.8000,   0.0000, 598.4000, 344.0000],
#          [478.4000, 192.0000, 598.4000, 361.6000]]]), 'labels': tensor([[15, 15, 15, 15, 15, 15, 15, 15, 15, 13, 13, 13, 13]]), 'image_id': ['001766']}
# 1
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[ 99.2000,   0.0000, 548.8000, 416.0000]]]), 'labels': tensor([[8]]), 'image_id': ['001768']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 83.2000,  96.0000, 347.2000, 299.2000],
#          [  1.6000, 363.2000, 190.4000, 536.0000],
#          [105.6000, 566.4000, 347.2000, 792.0000]]]), 'labels': tensor([[9, 9, 9]]), 'image_id': ['001771']}
# 1
# torch.Size([1, 3, 802, 600])
# {'boxes': tensor([[[311.1760, 393.0481, 469.9720, 489.3048]]]), 'labels': tensor([[15]]), 'image_id': ['001772']}
# 2
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[180.1802, 391.0340, 522.5225, 583.8480],
#          [410.8108, 172.9920, 527.9279, 201.8240]]]), 'labels': tensor([[19, 15]]), 'image_id': ['001775']}
# 7
# torch.Size([1, 3, 600, 898])
# {'boxes': tensor([[[ 80.8383, 707.6240, 353.8922, 793.8320],
#          [100.5988, 770.4840, 305.3892, 896.2040],
#          [102.3952, 113.1480, 211.9761, 310.7080],
#          [176.0479,   7.1840, 598.2036, 890.8160],
#          [ 37.7246, 290.9520, 201.1976, 553.1680],
#          [  0.0000, 165.2320, 105.9880, 346.6280],
#          [202.9940, 713.0120, 391.6168, 777.6680]]]), 'labels': tensor([[ 5,  9,  9, 11,  9, 16,  5]]), 'image_id': ['001777']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 60.8000, 153.6000, 452.8000, 644.8000]]]), 'labels': tensor([[12]]), 'image_id': ['001778']}
# 5
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[133.3333, 272.1020, 457.6577, 709.9880],
#          [  3.6036, 416.2620, 295.4955, 899.1980],
#          [ 45.0450,   0.0000, 297.2973, 212.6360],
#          [  0.0000,   0.0000, 108.1081, 286.5180],
#          [  0.0000, 457.7080,  50.4505, 641.5120]]]), 'labels': tensor([[14,  7,  7,  7,  7]]), 'image_id': ['001780']}
# 1
# torch.Size([1, 3, 600, 699])
# {'boxes': tensor([[[ 92.3077, 102.0540, 598.6014, 697.6020]]]), 'labels': tensor([[3]]), 'image_id': ['001782']}
# 1
# torch.Size([1, 3, 600, 896])
# {'boxes': tensor([[[  1.7910, 342.2720, 598.2090, 894.2080]]]), 'labels': tensor([[15]]), 'image_id': ['001784']}
# 1
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[  0.0000, 109.9220, 596.3964, 899.1980]]]), 'labels': tensor([[15]]), 'image_id': ['001785']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[160.0000, 233.6000, 553.6000, 441.6000]]]), 'labels': tensor([[3]]), 'image_id': ['001787']}
# 5
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[132.8000,   0.0000, 459.2000, 252.8000],
#          [155.2000, 313.6000, 408.0000, 515.2000],
#          [115.2000, 579.2000, 414.4000, 798.4000],
#          [328.0000, 572.8000, 443.2000, 616.0000],
#          [372.8000, 569.6000, 598.4000, 761.6000]]]), 'labels': tensor([[19, 19, 19, 15, 15]]), 'image_id': ['001789']}
# 3
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[206.4000,  97.6000, 553.6000, 438.4000],
#          [110.4000, 241.6000, 798.4000, 598.4000],
#          [548.8000,   0.0000, 798.4000, 424.0000]]]), 'labels': tensor([[15, 15, 11]]), 'image_id': ['001793']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[224.0000, 283.2000, 448.0000, 480.0000]]]), 'labels': tensor([[15]]), 'image_id': ['001795']}
# 3
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[  0.0000,   0.0000, 593.6000, 796.8000],
#          [  4.8000,   6.4000, 598.4000, 422.4000],
#          [ 54.4000, 280.0000, 406.4000, 552.0000]]]), 'labels': tensor([[18, 15, 15]]), 'image_id': ['001797']}
# 5
# torch.Size([1, 3, 600, 765])
# {'boxes': tensor([[[ 27.5510, 425.3400, 567.8571, 647.1900],
#          [104.0816,  59.6700, 540.3061, 397.8000],
#          [ 18.3673,  21.4200, 405.6122, 136.1700],
#          [134.6939, 628.8300, 541.8367, 763.4700],
#          [437.7551,  18.3600, 596.9388, 217.2600]]]), 'labels': tensor([[10, 15, 15, 15, 15]]), 'image_id': ['001799']}
# 2
# torch.Size([1, 3, 800, 600])
# {'boxes': tensor([[[288.0000,   1.6000, 796.8000, 593.6000],
#          [113.6000, 132.8000, 592.0000, 385.6000]]]), 'labels': tensor([[18, 15]]), 'image_id': ['001800']}
# 14
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[308.8000, 494.4000, 464.0000, 644.8000],
#          [278.4000, 280.0000, 516.8000, 464.0000],
#          [276.8000, 187.2000, 374.4000, 254.4000],
#          [259.2000, 137.6000, 328.0000, 188.8000],
#          [248.0000, 515.2000, 374.4000, 620.8000],
#          [227.2000, 308.8000, 446.4000, 409.6000],
#          [240.0000, 198.4000, 340.8000, 249.6000],
#          [240.0000, 152.0000, 308.8000, 187.2000],
#          [259.2000,   0.0000, 348.8000,  94.4000],
#          [252.8000,  62.4000, 283.2000, 102.4000],
#          [276.8000, 508.8000, 364.8000, 694.4000],
#          [328.0000,   0.0000, 582.4000,  67.2000],
#          [257.6000, 116.8000, 292.8000, 136.0000],
#          [267.2000, 260.8000, 332.8000, 296.0000]]]), 'labels': tensor([[14, 14, 14, 14, 15, 15, 15, 15,  7,  7,  7,  7, 14, 14]]), 'image_id': ['001801']}
# 4
# torch.Size([1, 3, 915, 600])
# {'boxes': tensor([[[349.5300, 499.3903, 658.8000, 598.1708],
#          [484.9500, 206.7073, 686.2500, 327.4390],
#          [387.9600, 107.9268, 697.2300, 294.5122],
#          [285.4800, 212.1951, 684.4200, 380.4878]]]), 'labels': tensor([[10, 10, 15, 15]]), 'image_id': ['001806']}
# 6
# torch.Size([1, 3, 600, 901])
# {'boxes': tensor([[[205.4054, 520.7780, 401.8018, 738.8200],
#          [243.2432, 360.4000, 387.3874, 531.5900],
#          [187.3874,  95.5060, 344.1441, 351.3900],
#          [178.3784, 592.8580, 347.7477, 652.3240],
#          [183.7838, 427.0740, 331.5315, 479.3320],
#          [151.3513, 201.8240, 302.7027, 268.4980]]]), 'labels': tensor([[13, 13, 13, 15, 15, 15]]), 'image_id': ['001807']}
# 3
# torch.Size([1, 3, 688, 600])
# {'boxes': tensor([[[345.3760,  11.0092, 503.6160, 115.5963],
#          [374.2720,  24.7706, 467.8400, 105.9633],
#          [345.3760, 452.7523, 632.9600, 591.7431]]]), 'labels': tensor([[20, 15, 18]]), 'image_id': ['001809']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[270.4000, 416.0000, 427.2000, 580.8000],
#          [ 80.0000,   0.0000, 598.4000, 376.0000]]]), 'labels': tensor([[20, 15]]), 'image_id': ['001810']}
# 1
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 56.0000,   0.0000, 398.4000, 588.8000]]]), 'labels': tensor([[8]]), 'image_id': ['001816']}
# 1
# torch.Size([1, 3, 600, 904])
# {'boxes': tensor([[[  3.6145, 202.4960, 598.1927, 902.1920]]]), 'labels': tensor([[3]]), 'image_id': ['001818']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[198.4000, 145.6000, 395.2000, 577.6000],
#          [ 94.4000,   6.4000, 179.2000,  83.2000]]]), 'labels': tensor([[7, 7]]), 'image_id': ['001821']}
# 2
# torch.Size([1, 3, 600, 800])
# {'boxes': tensor([[[ 60.8000,   0.0000, 478.4000, 643.2000],
#          [  3.2000,   0.0000, 593.6000, 798.4000]]]), 'labels': tensor([[ 8, 12]]), 'image_id': ['001825']}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-e470dd4aaff6> in <module>
# ----> 1 for i,(img,target) in enumerate(loader):
#       2     print(img.shape)
#       3     print(target)
#       4 #     temp = model(img)
#       5 #     rpn_offset, rpn_score, rois,roi_indices,anchors=rpn(temp,img,1)
#
# ~/opt/anaconda3/envs/inf558/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/opt/anaconda3/envs/inf558/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/opt/anaconda3/envs/inf558/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/opt/anaconda3/envs/inf558/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/Desktop/Computer Vision/faster-rcnn/data/dataset.py in __getitem__(self, idx)
#      51                 std=[0.229, 0.224, 0.225])
#      52                 ])(Image.open(img_path).convert("RGB"))
# ---> 53         anno = ET.parse(os.path.join(self.root_dir,"Annotations",idx+".xml"))
#      54         bbox = list()
#      55         label = list()
#
# ~/opt/anaconda3/envs/inf558/lib/python3.7/xml/etree/ElementTree.py in parse(source, parser)
#    1195     """
#    1196     tree = ElementTree()
# -> 1197     tree.parse(source, parser)
#    1198     return tree
#    1199
#
# ~/opt/anaconda3/envs/inf558/lib/python3.7/xml/etree/ElementTree.py in parse(self, source, parser)
#     596                     # It can be used to parse the whole source without feeding
#     597                     # it with chunks.
# --> 598                     self._root = parser._parse_whole(source)
#     599                     return self._root
#     600             while True:
#
# KeyboardInterrupt:

# %%
def bbox_iou(roi,bbox):
    top_left_intersection = np.maximum(roi[:,None,:2],bbox[:,:2])
    bottom_right_intersection = np.minimum(roi[:,None,2:],bbox[:,2:])
    
    area_i = np.prod(bottom_right-top_left,axis=2)*(top_left<bottom_right).all(axis=2)
    area_roi = np.prod(roi[:,2:] - roi[:,:2],axis=1)
    area_bbox = np.prod(bbox[:,2:] - bbox[:,:2],axis=1)
    return area_i / (area_roi.reshape(-1,1)+area_bbox.reshape(1,-1)-area_i)

# %%
bbox =target["boxes"][0].numpy()
roi = rois.detach().numpy()

# %%
max_iou = bbox_iou(roi,bbox).max(axis=1)

# %%
np.where(max_iou>0.5)[0]

# %%
bbox[:,:][0]

# %%
roi[:,None,:][0]

# %%
import numpy as np
torch.maximum(roi[:,None,:2],bbox[:,:2])[0]

# %%
top_left = np.maximum(roi[:,None,:2],bbox[:,:2])
bottom_right = np.minimum(roi[:,None,2:],bbox[:,2:])

area_i = np.prod(bottom_right-top_left,axis=2)*(top_left<bottom_right).all(axis=2)

# %%
area_i.shape

# %%
area_roi = np.prod(roi[:,2:] - roi[:,:2],axis=1)
area_bbox = np.prod(bbox[:,2:] - bbox[:,:2],axis=1)

# %%
torch.as_tensor([[1,2,3],[2,3,4]]).shape
# Out:
# torch.Size([2, 3])
